# %%
print("sai ram")
# Out:
# sai ram

# %%
name = "python"
age = 20
height = 5.8
data_course = True

# %%
type (age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %% [markdown]
# ## Variable

# %%
name_student = "sri"

# %%
name student = "sri"
# Out:
#   Cell In[8], line 1
#     name student = "sri"
#          ^
# SyntaxError: invalid syntax

# %%
_age = 40

# %%
40dfgh = 40
# Out:
#   Cell In[10], line 1
#     40dfgh = 40
#      ^
# SyntaxError: invalid decimal literal

# %%
L =" friyh"

# %%
A =" rtyu"

# %%
a = "tyum"

# %%
a
# Out:
# 'tyum'

# %%
A
# Out:
# ' rtyu'

# %%
a = "fyu5*nggji"
print(a)
# Out:
# fyu5*nggji

# %%
a = 10
b = 60
print(a+b)
# Out:
# 70

# %%
a = 10
b = 60
a+b
# Out:
# 70

# %%
a = 10
b = 60
c = a+b
c
# Out:
# 70

# %%
a = 40
_e = 70
c = a-_e
print(c)
# Out:
# -30

# %%
a/b
a
# Out:
# 40

# %%
10-20
# Out:
# -10

# %%
20+89
# Out:
# 109

# %%
80/2
# Out:
# 40.0

# %%
80%2
# Out:
# 0

# %%
80//2
# Out:
# 40

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
2**5
# Out:
# 32

# %%
students = -40
abs(students)
# Out:
# 40

# %%
10*2
# Out:
# 20

# %% [markdown]
# ## comparisison operators

# %%
a = 2
b = 3
2==3
# Out:
# False

# %%
2!=4
# Out:
# True

# %%
2>5
# Out:
# False

# %%
3<5
# Out:
# True

# %%
3<=4
# Out:
# True

# %%
5>=5
# Out:
# True

# %%
a == b
# Out:
# False

# %% [markdown]
# ## logical operators

# %%
5>3 and 4>2
# Out:
# True

# %%
5>3 && 4>2
# Out:
#   Cell In[47], line 1
#     5>3 && 4>2
#          ^
# SyntaxError: invalid syntax

# %%
5 == 2 and 5==5
# Out:
# False

# %%
6>4 or 6>6
# Out:
# True

# %%
not(6>7)
# Out:
# True

# %% [markdown]
# ## Assignment operators

# %%
x = 10

# %%
x += 10
x
# Out:
# 20

# %%
x -= 10
x
# Out:
# 10

# %%
x *= 10
x
# Out:
# 100

# %%
y = 10
y /= 10
y
# Out:
# 1.0

# %%
y =20
y //= 20
y
# Out:
# 1

# %%
z = 6
z %= 2
z
# Out:
# 0

# %%
y
# Out:
# 1

# %% [markdown]
# ## membership operator

# %%
'l' in "lasya"
# Out:
# True

# %%
'l' not in "lasya"
# Out:
# False

# %%
"z" not in "lasya"
# Out:
# True

# %% [markdown]
# ## identity operators

# %%
a =[1,2,3,4,5]
b = a
c = [1,2,3,4,5]

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
a is c
# Out:
# False

# %%
a is not c
# Out:
# True
