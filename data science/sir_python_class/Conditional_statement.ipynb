# %% [markdown]
# ### What are Conditional Statements?
#
# Conditional statements are the decision-making constructs in programming. They allow your program to:
#
# - Choose between different paths of execution
# - Respond differently based on user input
# - Handle different scenarios automatically
# - Create intelligent, adaptive programs

# %%
line by line 

line1
line2 
line3

# %%
if rainging is True:
    raining take an umbrellse 
else: don't

if money is True:
    buy item 
else:
    dont buy 
    
score = 30 
   
if score > 35:      # 0 false
    pass 
else:
    fail
    
if 
elif 
elif
else

# %%
# these decision depends on your boolean condiion ture and false

# %% [markdown]
# ## The if statement.
#
# Executes a block of code only if a condition is True . If the condition is False , the code block is skipped
# entierly.

# %%
# syntax: 

if condition:     # True or False
    # code to execute if condition is True 
    # This block must be indented (4 spaces or 1 tab)
# Code outside the if block run regardless

# %%
## basic eligiblity check 

age = 18 

if age >= 18:   # True     
    print("You are eligible to vote.")      # this block will execute only if condition is True
    print("Please register at your local office.")
print("Thank you for checking!!")
# Out:
# You are eligible to vote.
# Please register at your local office.
# Thank you for checking!!

# %%
age = 15 

if age >= 18:   # True     
    print("You are eligible to vote.")      # this block will execute only if condition is True
    print("Please register at your local office.")
print("Thank you for checking!!")
# Out:
# Thank you for checking!!

# %%
## Password strenght checker 

password = "some123123"

if len(password) >= 8 and is_num_present and is_capital_alpha_present and has_special_char:
    print("Password is strong enough!")

print("Password check complete.")
# Out:
# Password is strong enough!
# Password check complete.

# %%
## it should contain number nad special char and 10 lenght

# %% [markdown]
# ## The if-else statement
#
# Provides two paths: one for when the condition is True, another for when it's False.
# One of the two blocks will always execute.

# %%
# syntax 

if condition:  
    # if condition is true 
    # block of code to execute
else: 
    # Code if the condition is False

# %%
## Temperature Decision 

temperture = 15 

if temperture > 25:     # False
    print("It's a hot day!")        # execute when conditin is True
    print("Stay hydrated")      
else:           
    print("it's not hot day")       # execute when conditin is false
    print("Enjoy cool weather!")
# Out:
# it's not hot day
# Enjoy cool weather!

# %%
temperture > 25
# Out:
# False

# %%
temperture = 35 

if temperture > 25:         # True
    print("It's a hot day!")
    print("Stay hydrated")
else:
    print("it's not hot day")
    print("Enjoy cool weather!")
# Out:
# It's a hot day!
# Stay hydrated

# %%
temperture > 25
# Out:
# True

# %%
## Even or odd number 

number = 3 

if number % 2 == 0:     # flase
    print(f"{number} is even")
else:
    print(f"{number} is odd.")

# %%
number = 7
number % 2 == 0
# Out:
# False

# %%
## ATM withdrawal system 

balance = 500 
withdrawal = 600

if withdrawal <= balance:
    balance = balance - withdrawal 
    print(f"Withdrawal successful! remaining balance : {balance} Rupees")
else:
    print("Insufficient Funds!")
    print(f"Your current balance is {balance}")
# Out:
# Insufficient Funds!
# Your current balance is 500

# %%
balance = 500 
withdrawal = 130

if withdrawal <= balance:
    balance = balance - withdrawal 
    print(f"Withdrawal successful! remaining balance : {balance} Rupees")
else:
    print("Insufficient Funds!")
    print(f"Your current balance is {balance}")
# Out:
# Withdrawal successful! remaining balance : 370 Rupees

# %%
balance = 500
print(balance)

balance = balance - 200 
print(balance)
# Out:
# 500
# 300

# %%
## login system 

username = input("Enter the user")
password = input("Enter the password")

if username == "admin" and password == "pass123":
    print("Login successfull")
else:
    print("login failed")
    print("invalid username or password")
# Out:
# login failed
# invalid username or password

# %% [markdown]
# ## The if-elif-else ladder
#
# Used when you have multiple exclusive conditions to check. Python checks each condition in order and
# executes the first True block it finds, then skips all remaining conditions.

# %%
## syntax       # if-elif-else ladder

if condition1:  
    # Code for condition1 if True 
elif condition2:
    # Code for condition2 if True (only checked if condition1 is False)
elif condtion3:
    # Code for condition3 if True (only checked if condition1 and condition2 is False)
else:
    # code if all condition are false(optional)
